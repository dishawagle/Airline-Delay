# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")
# %matplotlib inline
from collections import Counter
import folium
import json
from itertools import islice
from html import HTML
from IPython.display import HTML

# %%
air = pd.read_csv('/home/alien/Downloads/airports.csv')
auto1 =pd.read_csv('/home/alien/Downloads/1987.csv',nrows = 400000)
auto2 =pd.read_csv('/home/alien/Downloads/1988.csv',nrows = 400000)
auto3 =pd.read_csv('/home/alien/Downloads/1989.csv',nrows = 400000)
auto4 =pd.read_csv('/home/alien/Downloads/1990.csv',nrows = 400000)
auto5 =pd.read_csv('/home/alien/Downloads/1991.csv',nrows = 400000)
auto6 =pd.read_csv('/home/alien/Downloads/1992.csv',nrows = 400000)
auto7 =pd.read_csv('/home/alien/Downloads/1993.csv',nrows = 400000)
auto8 =pd.read_csv('/home/alien/Downloads/1994.csv',nrows = 400000)
auto9 =pd.read_csv('/home/alien/Downloads/1995.csv',nrows = 400000)
auto10 =pd.read_csv('/home/alien/Downloads/1996.csv',nrows = 400000)
auto11 =pd.read_csv('/home/alien/Downloads/1997.csv',nrows = 400000)
auto12 =pd.read_csv('/home/alien/Downloads/1998.csv',nrows = 400000)
auto13 =pd.read_csv('/home/alien/Downloads/1999.csv',nrows = 400000)
auto14 =pd.read_csv('/home/alien/Downloads/2000.csv',nrows = 400000)
auto15 =pd.read_csv('/home/alien/Downloads/2001.csv',nrows = 400000)
auto16 =pd.read_csv('/home/alien/Downloads/2002.csv',nrows = 400000)
auto17 =pd.read_csv('/home/alien/Downloads/2003.csv',nrows = 400000)
auto18 =pd.read_csv('/home/alien/Downloads/2004.csv',nrows = 400000)
auto19 =pd.read_csv('/home/alien/Downloads/2005.csv',nrows = 400000)
auto20 =pd.read_csv('/home/alien/Downloads/2006.csv',nrows = 400000)
auto21 =pd.read_csv('/home/alien/Downloads/2007.csv',nrows = 400000)
auto22 =pd.read_csv('/home/alien/Downloads/2008.csv',nrows = 400000)

# %%
def inline_map(map):
    """
    Embeds the HTML source of the map directly into the IPython notebook.

    This method will not work if the map depends on any files (json data). Also this uses
    the HTML5 srcdoc attribute, which may not be supported in all browsers.
    """
    map._build_map()
    return HTML('<iframe srcdoc="{srcdoc}" style="width: 100%; height: 510px; border: none"></iframe>'.format(srcdoc=map.HTML.replace('"', '&quot;')))

def embed_map(map, path="map.html"):
    """
    Embeds a linked iframe to the map into the IPython notebook.

    Note: this method will not capture the source of the map into the notebook.
    This method should work for all maps (as long as they use relative urls).
    """
    map.create_map(path=path)
    return HTML('<iframe src="files/{path}" style="width: 100%; height: 510px; border: none"></iframe>'.format(path=path))

# %%
origin = Counter(auto1["Origin"]) + Counter(auto2["Origin"]) + Counter(auto3["Origin"]) + Counter(auto4["Origin"]) + Counter(auto5["Origin"]) + Counter(auto6["Origin"]) + Counter(auto7["Origin"]) + Counter(auto8["Origin"]) + Counter(auto9["Origin"]) + Counter(auto10["Origin"]) + Counter(auto11["Origin"]) + Counter(auto12["Origin"]) + Counter(auto13["Origin"]) + Counter(auto14["Origin"]) + Counter(auto15["Origin"]) + Counter(auto16["Origin"]) + Counter(auto17["Origin"]) + Counter(auto18["Origin"]) + Counter(auto19["Origin"]) + Counter(auto20["Origin"]) + Counter(auto21["Origin"]) + Counter(auto22["Origin"])
dest = Counter(auto1["Dest"]) + Counter(auto2["Dest"]) + Counter(auto3["Dest"]) + Counter(auto4["Dest"]) + Counter(auto5["Dest"]) + Counter(auto6["Dest"]) + Counter(auto7["Dest"]) + Counter(auto8["Dest"]) + Counter(auto9["Dest"]) + Counter(auto10["Dest"]) + Counter(auto11["Dest"]) + Counter(auto12["Dest"]) + Counter(auto13["Dest"]) + Counter(auto14["Dest"]) + Counter(auto15["Dest"]) + Counter(auto16["Dest"]) + Counter(auto17["Dest"]) + Counter(auto18["Dest"]) + Counter(auto19["Dest"]) + Counter(auto20["Dest"]) + Counter(auto21["Dest"]) + Counter(auto22["Dest"])

df_origin = pd.DataFrame.from_dict(origin, orient='index').reset_index()
df_origin = df_origin.rename(columns={'index':'iata', 0:'count'})


df_dest = pd.DataFrame.from_dict(dest, orient='index').reset_index()
df_dest = df_dest.rename(columns={'index':'iata', 0:'count'})

origin_results = pd.merge(left=df_origin,right=air, left_on='iata', right_on='iata')
dest_results = pd.merge(left=df_dest,right=air, left_on='iata', right_on='iata')

#print results
sorted_origin =origin_results.sort_index(by=['count'], ascending=[False])
sorted_dest =dest_results.sort_index(by=['count'], ascending=[False])

# %%
sorted_origin.head()
# Out:
#     iata   count                            airport               city state  \
# 154  ATL  445149  William B Hartsfield-Atlanta Intl            Atlanta    GA
# 225  ORD  442835       Chicago O'Hare International            Chicago    IL
# 208  DFW  367466    Dallas-Fort Worth International  Dallas-Fort Worth    TX
# 64   LAX  308175          Los Angeles International        Los Angeles    CA
# 63   PHX  281311   Phoenix Sky Harbor International            Phoenix    AZ
#
#     country        lat        long
# 154     USA  33.640444  -84.426944
# 225     USA  41.979595  -87.904464
# 208     USA  32.895951  -97.037200
# 64      USA  33.942536 -118.408074
# 63      USA  33.434167 -112.008056

# %%
sorted_origin.tail()
# Out:
#     iata  count         airport        city state country        lat  \
# 237  MKK     30         Molokai  Kaunakakai    HI     USA  21.152886
# 246  PSE     22       Mercedita       Ponce    PR     USA  18.008303
# 184  CKB      6         Benedum  Clarksburg    WV     USA  39.296639
# 317  OGD      1  Ogden-Hinckley       Ogden    UT     USA  41.195944
# 250  CYS      1        Cheyenne    Cheyenne    WY     USA  41.155722
#
#            long
# 237 -157.096256
# 246  -66.563012
# 184  -80.228083
# 317 -112.012175
# 250 -104.811838

# %%
sorted_dest.head()
# Out:
#     iata   count                            airport               city state  \
# 225  ORD  466028       Chicago O'Hare International            Chicago    IL
# 154  ATL  463976  William B Hartsfield-Atlanta Intl            Atlanta    GA
# 208  DFW  381855    Dallas-Fort Worth International  Dallas-Fort Worth    TX
# 63   LAX  313721          Los Angeles International        Los Angeles    CA
# 62   PHX  289144   Phoenix Sky Harbor International            Phoenix    AZ
#
#     country        lat        long
# 225     USA  41.979595  -87.904464
# 154     USA  33.640444  -84.426944
# 208     USA  32.895951  -97.037200
# 63      USA  33.942536 -118.408074
# 62      USA  33.434167 -112.008056

# %%
sorted_dest.tail()
# Out:
#     iata  count         airport        city state country        lat  \
# 247  PSE     26       Mercedita       Ponce    PR     USA  18.008303
# 185  CKB      6         Benedum  Clarksburg    WV     USA  39.296639
# 318  OGD      4  Ogden-Hinckley       Ogden    UT     USA  41.195944
# 251  CYS      1        Cheyenne    Cheyenne    WY     USA  41.155722
# 234  PVU      1      Provo Muni       Provo    UT     USA  40.219194
#
#            long
# 247  -66.563012
# 185  -80.228083
# 318 -112.012175
# 251 -104.811838
# 234 -111.723361

# %%
airports_origin = []
airports_origin.append(json.loads(sorted_origin.to_json(orient='index')))
airports_dest = []
airports_dest.append(json.loads(sorted_dest.to_json(orient='index')))

# %% [raw]
# Busiest Airports by Origin

# %%
origin_map = folium.Map(location=[40, -99], zoom_start=4)
ARR_COLOR = '#2171b5'
for airport in islice(airports_origin,None):
    for i in airport:

        lat =  float(airport[i]['lat'])
        lon = float(airport[i]['long'])
        circleradius = int(airport[i]['count'])/3
        label = str(airport[i]['airport'])+", "+str(airport[i]['city'])+" Total flights: "+str(airport[i]['count'])
        origin_map.circle_marker(location=[lat, lon], radius=circleradius*2,popup=label,line_color=ARR_COLOR,fill_color=ARR_COLOR)

inline_map(origin_map)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#   <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/andrewgiessel/leafletstuff/master/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_e797a5d2e5f64298902961e90586a059&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_e797a5d2e5f64298902961e90586a059', {
#                                        center:[40, -99],
#                                        zoom: 4,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       /*
#       addition of the image layers
#       */
#
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#
#
#       var circle_1 = L.circle([37.70097028, -113.098575], 248, {
#                             color: '#2171b5',
#                             fillColor: '#2171b5',
#                             fillOpacity: 0.6
#                             });
#       circle_1.bindPopup(&quot;Cedar City Muni, Cedar City Total flights: 372&quot;);
#       circle_1._popup.options.maxWidth = 300;
#       map.addLayer(circle_1)
#
#       var circle_2 = L.circle([25.90683333, -97.42586111], 758, {
#                             color: '#2171b5',
#                             fillColor: '#2171b5',
#                             fillOpacity: 0.6
#                             });
#       circle_2.bindPopup(&quot;Brownsville/S.Padre Island International, Brownsville Total flights: 1137&quot;);
#       circle_2._popup.options.maxWidth = 300;
#       map.addLayer(circle_2)
#
#       var circle_3 = L.circle([42.74811944, -73.80297861], 14376, {
#                             color: '#2171b5',
#                             fillColor: '#2171b5',
#                             fillOpacity: 0.6
#                             });
#       circle_3.bindPopup(&quot;Albany Cty, Albany Total flights: 21564&quot;);
#       circle_3._popup.options.maxWidth = 300;
#       map.addLayer(circle_3)
#
#       var circle_4 = L.circle([38.28908722, -104.4965722], 478, {
#                             color: '#2171b5',
#                             fillColor: '#2171b5',
#                             fillOpacity: 0.6
#                             });
#       circle_4.bindPopup(&quot;Pueblo Memorial, Pueblo Total flights: 719&quot;);
#       circle_4._popup.options.maxWidth = 300;
#       map.addLayer(circle_4)
#
#       var circle_5 = L.circle([32.33313333, -88.75120556], 390, {
#                             color: '#2171b5',
#                             fillColor: '#2171b5',
#                             fillOpacity: 0.6
#                             });
#       circle_5.bindPopup(&quot;Key , Meridian Total flights: 587&quot;);
#       circle_5._popup.options.maxWidth = 300;
#       map.addLayer(circle_5)
#
#       var circle_6 = L.circle([32.11608333, -110.9410278], 21302, {
#                             color: '#2171b5',
#                             fillColor: '#2171b5',
#                             fillOpacity: 0.6
#                             });
#       circle_6.bindPopup(&quot;Tucson International, Tucson Total flights: 31955&quot;);
#       circle_6._popup.options.maxWidth = 300;
#       map.addLayer(circle_6)
#
#       var circle_7 = L.circle([41.26389889, -72.8871], 392, {
#                             color: '#2171b5',
#                             fillColor: '#2171b5',
#                             fillOpacity: 0.6
#                             });
#       circle_7.bindPopup(&quot;Tweed-New Haven, New Haven Total flights: 588&quot;);
#       circle_7._popup.options.maxWidth = 300;
#       map.addLayer(circle_7)
#
#       var circle_8 = L.circle([35.04241667, -89.97666667], 59056, {
#                             color: '#2171b5',
#                             fillColor: '#2171b5',
#                             fillOpacity: 0.6
#                             });
#       circle_8.bindPopup(&quot;Memphis International, Memphis Total flights: 88584&quot;);
#       circle_8._popup.options.maxWidth = 300;
#       map.addLayer(circle_8)
#
#       var circle_9 = L.circle([34.20061917, -118.3584969], 30746, {
#                             color: '#2171b5',
#                             fillColor: '#2171b5',
#                             fillOpacity: 0.6
#                             });
#       circle_9.bindPopup(&quot;Burbank-Glendale-Pasadena, Burbank Total flights: 46121&quot;);
#       circle_9._popup.options.maxWidth = 300;
#       map.addLayer(circle_9)
#
#       var circle_10 = L.circle([44.47300361, -73.1503125], 4872, {
#                             color: '#2171b5',
#                             fillColor: '#2171b5',
#                             fillOpacity: 0.6
#                             });
#       circle_10.bindPopup(&quot;Burlington International, Burlington Total flights: 7310&quot;);
#       circle_10._popup.options.maxWidth = 300;
#       map.addLayer(circle_10)
#
#       var circle_11 = L.circle([71

# %% [raw]
# Busiest Airports by Destination

# %%
dest_map = folium.Map(location=[40, -99], zoom_start=4)
DEP_COLOR = '#238b45'
for airport in islice(airports_dest,None):
    for i in airport:

        lat =  float(airport[i]['lat'])
        lon = float(airport[i]['long'])
        circleradius = int(airport[i]['count'])/3
        label = str(airport[i]['airport'])+", "+str(airport[i]['city'])+" Total flights: "+str(airport[i]['count'])
        dest_map.circle_marker(location=[lat, lon], radius=circleradius*2,popup=label,line_color=DEP_COLOR,fill_color=DEP_COLOR)

inline_map(dest_map)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#   <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/andrewgiessel/leafletstuff/master/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_95470610b8bf400da21285d7532351b7&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_95470610b8bf400da21285d7532351b7', {
#                                        center:[40, -99],
#                                        zoom: 4,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       /*
#       addition of the image layers
#       */
#
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#
#
#       var circle_1 = L.circle([37.70097028, -113.098575], 248, {
#                             color: '#238b45',
#                             fillColor: '#238b45',
#                             fillOpacity: 0.6
#                             });
#       circle_1.bindPopup(&quot;Cedar City Muni, Cedar City Total flights: 372&quot;);
#       circle_1._popup.options.maxWidth = 300;
#       map.addLayer(circle_1)
#
#       var circle_2 = L.circle([25.90683333, -97.42586111], 762, {
#                             color: '#238b45',
#                             fillColor: '#238b45',
#                             fillOpacity: 0.6
#                             });
#       circle_2.bindPopup(&quot;Brownsville/S.Padre Island International, Brownsville Total flights: 1144&quot;);
#       circle_2._popup.options.maxWidth = 300;
#       map.addLayer(circle_2)
#
#       var circle_3 = L.circle([42.74811944, -73.80297861], 15126, {
#                             color: '#238b45',
#                             fillColor: '#238b45',
#                             fillOpacity: 0.6
#                             });
#       circle_3.bindPopup(&quot;Albany Cty, Albany Total flights: 22689&quot;);
#       circle_3._popup.options.maxWidth = 300;
#       map.addLayer(circle_3)
#
#       var circle_4 = L.circle([38.28908722, -104.4965722], 470, {
#                             color: '#238b45',
#                             fillColor: '#238b45',
#                             fillOpacity: 0.6
#                             });
#       circle_4.bindPopup(&quot;Pueblo Memorial, Pueblo Total flights: 707&quot;);
#       circle_4._popup.options.maxWidth = 300;
#       map.addLayer(circle_4)
#
#       var circle_5 = L.circle([32.33313333, -88.75120556], 402, {
#                             color: '#238b45',
#                             fillColor: '#238b45',
#                             fillOpacity: 0.6
#                             });
#       circle_5.bindPopup(&quot;Key , Meridian Total flights: 604&quot;);
#       circle_5._popup.options.maxWidth = 300;
#       map.addLayer(circle_5)
#
#       var circle_6 = L.circle([32.11608333, -110.9410278], 21598, {
#                             color: '#238b45',
#                             fillColor: '#238b45',
#                             fillOpacity: 0.6
#                             });
#       circle_6.bindPopup(&quot;Tucson International, Tucson Total flights: 32398&quot;);
#       circle_6._popup.options.maxWidth = 300;
#       map.addLayer(circle_6)
#
#       var circle_7 = L.circle([41.26389889, -72.8871], 394, {
#                             color: '#238b45',
#                             fillColor: '#238b45',
#                             fillOpacity: 0.6
#                             });
#       circle_7.bindPopup(&quot;Tweed-New Haven, New Haven Total flights: 591&quot;);
#       circle_7._popup.options.maxWidth = 300;
#       map.addLayer(circle_7)
#
#       var circle_8 = L.circle([35.04241667, -89.97666667], 61078, {
#                             color: '#238b45',
#                             fillColor: '#238b45',
#                             fillOpacity: 0.6
#                             });
#       circle_8.bindPopup(&quot;Memphis International, Memphis Total flights: 91618&quot;);
#       circle_8._popup.options.maxWidth = 300;
#       map.addLayer(circle_8)
#
#       var circle_9 = L.circle([44.47300361, -73.1503125], 4724, {
#                             color: '#238b45',
#                             fillColor: '#238b45',
#                             fillOpacity: 0.6
#                             });
#       circle_9.bindPopup(&quot;Burlington International, Burlington Total flights: 7087&quot;);
#       circle_9._popup.options.maxWidth = 300;
#       map.addLayer(circle_9)
#
#       var circle_10 = L.circle([71.2854475, -156.7660019], 308, {
#                             color: '#238b45',
#                             fillColor: '#238b45',
#                             fillOpacity: 0.6
#                             });
#       circle_10.bindPopup(&quot;Wiley Post Will Rogers Memorial, Barrow Total flights: 463&quot;);
#       circle_10._popup.options.maxWidth = 300;
#       map.addLayer(circle_10)
#
#       var circle_11 = L.circle([60
